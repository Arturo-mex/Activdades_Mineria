# %%
#Jaime Arturo Renteria Tamez 173876 001 409
import numpy as np
import math as mt
import copy as cp
import itertools
from itertools import combinations

#Use los datos en forma horizontal
l0=["A", "B", "C" , "D", "E"]

a=[1,0,1,0,1] #a
b=[0,1,1,1,1] #b
c=[1,1,1,0,1] #c
d=[1,0,0,0,0] #d
e=[0,1,1,1,1] #e

print(l0)
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# ['A', 'B', 'C', 'D', 'E']
# [1, 0, 1, 0, 1]
# [0, 1, 1, 1, 1]
# [1, 1, 1, 0, 1]
# [1, 0, 0, 0, 0]
# [0, 1, 1, 1, 1]

# %%
def longitud_lista(n):
    n=len(n)
    return n

def cantidad_lista(n):
    aux=0 
    for i in n:
        if i==1:
            aux=aux+1
    return aux

def comparar_umbraln1(cantidad,longitud):
    lumbral=0
    lumbral=cantidad/longitud
    if lumbral>0.5:
        lumbral=lumbral
        return lumbral

def nivel1(lumbral,n):
    aux=[]
    if lumbral!=None:
        aux.append(l0[n])
    return aux


def combiancionesn1(aux2):
    res=0
    aux3=[]
    for i in [2]:
        res=combinations(aux2,i)
        for x in res:
            aux3.append(''.join(x))           
    return aux3


def nivel2(lumbral):
    aux=[]
    for i in range(len(lumbral)):
        if i!=None and i>0.5 and i>0.6:
            aux.append(l0[i])
    return aux

    
def combiancionesn2(aux2):
    res=0
    aux3=[]
    for i in [3]:
        res=combinations(aux2,i)
        for x in res:
            aux3.append(''.join(x))
            
    return aux3

def juntalumbral(lumbral):
    lumbralaux=[]
    lumbralaux.append(lumbral)
    return lumbralaux


n=0
n1=0
aux=0
aux1=0
resn=[]
resn1comb=[]
resn2=[]
resn3=[]
resn3aux=[]
lumbral=0
lumbralaux=0
lumbralaux2=[]

n=longitud_lista(a)
aux=cantidad_lista(a)
lumbral=comparar_umbraln1(aux,n)
aux1=nivel1(lumbral,n1)
resn=resn+aux1
print('veces que se repite a=',aux,'n=',n,'lumbral=',lumbral)
lumbralaux=juntalumbral(lumbral)
lumbralaux2=lumbralaux2+lumbralaux

n1=n1+1
n=longitud_lista(b)
aux=cantidad_lista(b)
lumbral=comparar_umbraln1(aux,n)
aux1=nivel1(lumbral,n1)
resn=resn+aux1
print('veces que se repite b=',aux,'n=',n,'lumbral=',lumbral)
lumbralaux=juntalumbral(lumbral)
lumbralaux2=lumbralaux2+lumbralaux

n1=n1+1
n=longitud_lista(c)
aux=cantidad_lista(c)
lumbral=comparar_umbraln1(aux,n)
aux1=nivel1(lumbral,n1)
resn=resn+aux1
print('veces que se repite c=',aux,'n=',n,'lumbral=',lumbral)
lumbralaux=juntalumbral(lumbral)
lumbralaux2=lumbralaux2+lumbralaux

n1=n1+1
n=longitud_lista(d)
aux=cantidad_lista(d)
lumbral=comparar_umbraln1(aux,n)
aux1=nivel1(lumbral,n1)
resn=resn+aux1
print('veces que se repite d=',aux,'n=',n,'lumbral=',lumbral)
lumbralaux=juntalumbral(lumbral)
lumbralaux2=lumbralaux2+lumbralaux

n1=n1+1
n=longitud_lista(e)
aux=cantidad_lista(e)
lumbral=comparar_umbraln1(aux,n)
aux1=nivel1(lumbral,n1)
resn=resn+aux1
#resn2=resn2+resn
print('veces que se repite e=',aux,'n=',n,'lumbral=',lumbral)
lumbralaux=juntalumbral(lumbral)
lumbralaux2=lumbralaux2+lumbralaux
#1st nivel
print('El primer nivel es=',resn)
resn1comb=combiancionesn1(resn)
print('Combinaciones primer nivel es= ',resn1comb)

print(lumbralaux2)
print(len(lumbralaux2))
resn2=nivel2(lumbralaux2)

#2do nivel

print(resn2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-56ce3c8839a5> in <module>
#      71 lumbralaux2=[]
#      72
# ---> 73 n=longitud_lista(a)
#      74 aux=cantidad_lista(a)
#      75 lumbral=comparar_umbraln1(aux,n)
#
# NameError: name 'a' is not defined
